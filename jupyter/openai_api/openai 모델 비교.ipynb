# %% [markdown]
# # OpenAI API 전체 모델 비교 (2025년 10월 기준)
#
# 현재 OpenAI API에서 활용 가능한 대부분의 모델을 기능별로 분류하고, 주요 스펙과 비용을 하나의 표로 정리했습니다.
#
# 아래 표는 크게 **언어 모델, 이미지 모델, 오디오 모델, 기타 모델**로 구분되어 있으며, 각 모델의 특징과 활용 분야를 쉽게 비교할 수 있도록 구성했습니다.
#
# ---
#
# ### OpenAI API 전체 모델 비교표
#
# | 구분 | 모델 ID (API Name) | 주요 특징 및 활용 분야 | 컨텍스트 창 | 비용 (1백만 토큰 기준) |
# | :--- | :--- | :--- | :--- | :--- |
# | **최첨단 언어 모델<br>(Frontier)** | `gpt-5` | **최고 성능의 주력 모델.** 복잡한 추론, 전문적인 코드 생성, 다단계 작업을 수행하는 AI 에이전트 구축에 최적화되어 있습니다. | 400,000 | **입력:** $1.25<br>**출력:** $10.00 |
# | | `gpt-5-mini` | GPT-5의 지능을 유지하면서 **속도와 비용 효율성을 높인 균형 잡힌 모델.** 대부분의 상업용 AI 서비스에 적합합니다. | 400,000 | **입력:** $0.25<br>**출력:** $2.00 |
# | | `gpt-5-nano` | **가장 빠르고 저렴한 모델.** 텍스트 분류, 요약, 감정 분석 등 신속한 처리가 중요한 간단한 작업에 사용됩니다. | 400,000 | **입력:** $0.05<br>**출력:** $0.40 |
# | **멀티모달 언어 모델** | `gpt-4o` | **텍스트, 이미지, 오디오를 동시에 이해하고 생성**하는 멀티모달 모델. 실시간 음성 대화, 이미지 분석 기반 챗봇 등에 탁월합니다. | 128,000 | **입력:** $2.50<br>**출력:** $10.00 |
# | | `gpt-4o-mini` | `gpt-4o`의 **비용 효율적인 소형 버전.** 멀티모달 기능을 저렴하게 사용하고자 할 때 적합합니다. | 128,000 | **입력:** $0.15<br>**출력:** $0.60 |
# | **범용 언어 모델** | `gpt-4.1` | **매우 긴 컨텍스트 처리 능력**이 특징. 방대한 문서(법률, 연구) 분석 및 요약, 대규모 코드베이스 이해에 강점이 있습니다. | 1,047,576 | **입력:** $2.00<br>**출력:** $8.00 |
# | **이미지 모델** | `dall-e-3` | 텍스트 설명 기반 **고품질 이미지 생성.** 사용자의 복잡하고 상세한 요구사항을 정확하게 시각화합니다. 마케팅, 콘텐츠 제작에 사용됩니다. | 해당 없음 | **$0.04** / 이미지 (표준)<br>**$0.08** / 이미지 (HD) |
# | | `gpt-image-1` | 언어 모델과 통합되어 **더 높은 문맥 이해력을 바탕으로 이미지를 생성.** 대화를 통해 점진적으로 이미지를 수정하고 발전시키는 작업에 유리합니다. | 해당 없음 | **~ $0.04** / 이미지<br>(프롬프트 비용 별도) |
# | **오디오 모델** | `whisper-1` | **음성 → 텍스트 변환 (STT).** 다국어 지원, 높은 정확도로 회의록 작성, 인터뷰 녹취, 음성 명령 등에 활용됩니다. | 해당 없음 | **$0.006** / 분 |
# | | `tts-1` | **텍스트 → 음성 변환 (TTS).** 자연스러운 사람 목소리를 생성합니다. | 해당 없음 | **$0.015** / 1,000자 |
# | | `tts-1-hd` | `tts-1`의 **고음질 버전.** 오디오북, 전문 내레이션 등 높은 품질의 음성이 필요할 때 사용됩니다. | 해당 없음 | **$0.030** / 1,000자 |
# | **임베딩 모델<br>(검색/분석)** | `text-embedding-3-large` | **가장 높은 정확도**의 텍스트 임베딩 모델. 텍스트의 의미를 벡터로 변환하여 의미 기반 검색, 추천 시스템의 성능을 극대화합니다. | 8,191 | **$0.13** |
# | | `text-embedding-3-small` | **비용 효율적인 임베딩 모델.** `large`보다 저렴하지만 대부분의 검색, 클러스터링, 분류 작업에서 우수한 성능을 보입니다. | 8,191 | **$0.02** |
# | **콘텐츠 관리 모델** | `omni-moderation` | **유해 콘텐츠 식별.** 텍스트 및 이미지에서 폭력, 혐오 발언 등 부적절한 내용을 감지하여 안전한 서비스 환경을 구축하는 데 사용됩니다. | 해당 없음 | 무료 (베타) |
#
# *참고: `gpt-3.5-turbo`와 같은 이전 세대 모델도 여전히 사용 가능하지만, 특별한 목적(레거시 시스템 호환 등)이 아니라면 성능과 효율성이 더 뛰어난 최신 모델 사용이 권장됩니다.*
#
# ---
#
# ### 어떤 모델을 선택해야 할까?
#
# - **최고의 성능과 복잡한 작업:** `gpt-5`
# - **대부분의 웹/앱 서비스(가성비):** `gpt-5-mini`
# - **실시간 음성/이미지 상호작용:** `gpt-4o`
# - **긴 문서 분석:** `gpt-4.1`
# - **이미지 생성:** `dall-e-3`
# - **음성 처리:** `whisper-1` (음성→텍스트), `tts-1` (텍스트→음성)
# - **의미 기반 검색 기능 구현:** `text-embedding-3-small` (가성비) 또는 `text-embedding-3-large` (최고 성능)

# %%
import os
import openai
# from openai import OpenAI
openai.__version__
# Out:
# '2.0.1'

# %%
api_key_value = os.getenv('OPENAI_API_KEY')

# %%
import openai

# 환경 변수에서 API 키를 로드합니다.
client = openai.OpenAI()

def get_ai_response(model_name, prompt):
    """지정된 모델과 프롬프트를 사용하여 AI의 응답을 요청하는 함수"""
    try:
        response = client.chat.completions.create(
            model=model_name,
            messages=[{"role": "user", "content": prompt}]
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"오류가 발생했습니다: {e}"

# 이제 이 함수를 재사용하여 여러 모델을 테스트합니다.

# %%
import openai

# 1. 새로 발급받은 유효한 API 키를 여기에 직접 넣으세요.
client = openai.OpenAI() 

# 2. 실습 1 코드 실행
prompt = "딥러닝에 대해 비전공자가 이해하기 쉽게 설명하고, 실생활에 적용될 수 있는 미래 기술 예시를 3가지 들어줘."

try:
    # 3. 모델 이름 수정: gpt-3.5-turbo 등 공식 모델 사용
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": prompt}]
    )
    
    # 결과 출력
    answer = response.choices[0].message.content
    print("--- 성공적으로 받은 응답 ---")
    print(answer)

except Exception as e:
    # 키가 올바른데도 오류가 나면 다른 원인이 있을 수 있습니다.
    print(f"API 요청 오류가 발생했습니다: {e}")
# Out:
# --- 성공적으로 받은 응답 ---
# 딥러닝은 인공지능의 한 분야로, 인간 두뇌의 신경망을 모방한 알고리즘을 사용하여 데이터에서 패턴을 학습하는 기술입니다. 이를 통해 컴퓨터는 스스로 데이터를 분석하고 학습하여 문제를 해결할 수 있습니다.
#
# 1. 음성 인식 기술: 음성인식 기술은 딥러닝을 이용하여 사람의 음성을 인식하고 텍스트로 변환하는 기술을 말합니다. 이를 통해 스마트폰의 음성 비서나 음성으로 명령을 내리는 기술 등이 가능해지며, 향후 추억을 기반으로 한 음성 제어 기술이 올바르게 갖춰질 것으로 기대됩니다.
#
# 2. 자율주행 자동차: 딥러닝 기술은 자율주행 자동차의 발전에 중요한 역할을 합니다. 카메라, 레이더 및 다른 센서 데이터를 입력으로 사용하여 실시간으로 주변 환경을 이해하고 조작할 수 있습니다. 이를 활용하여 사람이 개입하지 않고도 자동차가 스스로 운전을 할 수 있는 기술을 완성할 수 있습니다.
#
# 3. 의료 진단 및 예측: 의료 분야에서는 딥러닝을 사용하여 X-레이 이미지, CT 스캔 및 기타 의료 영상을 분석하여 질병을 탐지하거나 진단하는 데 사용될 수 있습니다. 또한 환자 데이터를 바탕으로 개인 맞춤형 의학을 제시하고 질병 예방을 위한 예측 모델을 개발하는 데도 활용될 수 있습니다.

# %%
answer = response.choices[0].message.content
answer
# Out:
# '딥러닝은 인공지능의 한 분야로, 인간의 뇌를 모방하여 학습하고 추론하는 기술입니다. 간단히 말하면, 컴퓨터가 데이터를 학습하여 패턴을 파악하고 문제를 해결하는 과정을 말합니다.\n\n1. 얼굴 인식 기술: 딥러닝 기술을 활용하여 얼굴 인식 기술을 발전시킨 사례가 널리 사용되고 있습니다. 이를 통해 스마트폰의 얼굴 인식 잠금, 보안 시스템, CCTV 분석 등 다양한 분야에 적용될 수 있습니다.\n\n2. 음성 인식 기술: AI 스피커를 비롯한 음성 인식 기술이 딥러닝을 기반으로 발전하고 있습니다. 이를 통해 음성 명령으로 가전제품을 제어하거나, 음성 비서 기능을 제공하는 제품들이 많이 출시되고 있습니다.\n\n3. 의료 진닝: 의료 분야에서도 딥러닝 기술을 적용하여 질병 진단, 약물 발견, 영상 판독 등 다양한 응용이 가능합니다. 특히 의료 영상 분석을 통해 암 등 질병을 조기에 발견하는데 도움이 되고 있습니다.'

# %%
print("🚀 GPT-5-nano (빠르고 가벼운 모델)의 답변:")
print("-" * 50)
print(get_ai_response("gpt-5-nano", answer))
print("\n" * 2)
# Out:
# 🚀 GPT-5-nano (빠르고 가벼운 모델)의 답변:
# --------------------------------------------------
# 좋은 요약입니다. 다만 몇 가지 표현을 다듬으면 더 명확해질 것 같아요. 또한 간단한 보완도 곁들였습니다.
#
# 수정 및 다듬은 버전
# 1. 얼굴 인식 기술
# - 딥러닝을 활용한 얼굴 인식 기술은 스마트폰의 잠금 해제, 보안 시스템, CCTV 분석 등 다양한 분야에서 널리 활용되고 있습니다.
# - 대표적인 모델로 FaceNet, ArcFace 등과 같은 접근 방식이 있으며, 대규모 얼굴 데이터로 학습합니다.
#
# 2. 음성 인식 기술
# - 딥러닝에 기반한 음성 인식 기술은 AI 스피커를 비롯한 다양한 음성 인터페이스의 핵심이 되고 있습니다.
# - 이를 통해 음성 명령으로 가전제품을 제어하거나 음성 비서 기능을 제공하는 제품들이 많이 출시되고 있습니다.
#
# 3. 의료 진단/의료 영상 분석
# - 딥러닝은 의료 분야에서도 질병 진단, 약물 발견, 영상 판독 등 다양한 응용이 가능합니다.
# - 특히 의료 영상 분석을 통해 암 등 질환을 조기에 발견하는 데 도움이 되고 있습니다.
#
# 보완하면 좋을 추가 정보
# - 핵심 기술: 합성곱 신경망(CNN), 순환 신경망(RNN/LSTM), 트랜스포머 등과 같은 모델이 각각의 분야에서 널리 활용됩니다. 또한 대규모 데이터로의 사전 학습과 전이학습, 데이터 증강 기법도 중요한 역할을 합니다.
# - 일반적인 도전 과제: 데이터 편향과 프라이버시 문제, 악의적 활용 가능성, 해석 가능성과 신뢰성, 적은 데이터 환경에서의 성능 저하 등.
# - 윤리적 고려사항: 얼굴 인식의 프라이버시 및 감시 문제, 음성 데이터의 개인 정보 보호, 의료 데이터의 보안과 동의 여부 등 신중한 접근이 필요합니다.
# - 향후 동향: 멀티모달 학습(예: 영상+음성+의료 기록 결합), 온디바이드(엣지) AI, 파운데이션 모델의 의료 도메인 적용 확대 등.
#
# ...

# %%
# %%time 
response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[{"role": "user", "content": prompt}]
)
answer = response.choices[0].message.content

print("🧠 GPT-5 (가장 강력한 모델)의 답변:")
print("-" * 50)
print(answer)
# Out:
# 🧠 GPT-5 (가장 강력한 모델)의 답변:
# --------------------------------------------------
# 다음은 비전공자도 이해하기 쉽게 본 딥러닝 설명과, 실생활에 적용될 수 있는 미래 기술 3가지 예시입니다.
#
# 1) 딥러닝을 비전공자가 이해하기 쉽게 설명
# - 아이디어 한 줄 요약
#   - 딥러닝은 컴퓨터가 많은 예시를 보고 스스로 규칙을 찾아내는 “패턴 인식” 기술입니다. 사람처럼 직접 규칙을 하나씩 쓰지 않고, 데이터에서 규칙을 학습합니다.
# - 어떻게 작동하나
#   - 데이터 모으기: 사진, 음성, 글 등 다양한 예를 모아 집합(dataset)을 만듭니다.
#   - 모델 만들기: 뇌의 신경망처럼 연결된 여러 층의 계산 구조를 만들어 입력 데이터를 처리합니다. 이 구조를 “네트워크”라고 부릅니다.
#   - 학습하기: 모델이 내가 원하는 정답과 실제 예시의 차이를 줄이도록 가중치라는 내부 숫자들을 조정합니다. 이 과정을 학습(training)이라고 합니다.
#   - 추론하기: 학습이 끝난 모델에 새 데이터를 넣으면, 그 데이터에 대한 예측이나 결정(예: 사진에 무엇이 보이는지)을 내놓습니다.
# - 왜 강력하나
#   - 대량의 데이터에서 복잡한 패턴을 자동으로 찾아낼 수 있습니다. 예를 들어 이미지를 보고 고양이/개를 구분하거나, 음성을 텍스트로 바꾸는 것처럼 사람의 규칙을 하나씩 적지 않아도 됩니다.
# - 한계와 주의점
#   - 데이터에 따라 성능이 달라지며, 편향된 데이터로 학습하면 편향된 결과를 낼 수 있습니다.
#   - 데이터가 많아야 잘 배우지만, 데이터 수집과 저장, 개인정보 보호가 중요합니다.
#   - 모델의 내부가 복잡해 해석이 어려울 수 있어, 왜 그런 결과가 나왔는지 always 쉽게 설명하기 어려운 경우가 있습니다.
#
# 2) 실생활에 적용될 수 있는 미래 기술 3가지 예시
#
# 1) 개인 맞춤형 건강 관리 AI와 디지털 트윈 건강 관리
# - 무엇인가
# ...

# %%
# 학생 토론 유도:
# - nano 모델은 핵심을 간단히 요약하는 경향이 있고, gpt-5는 훨씬 더 깊이 있고 구조적인 답변을 제공합니다.
# - 어떤 상황에 nano를 쓰고, 어떤 상황에 gpt-5를 써야 할까요? (비용과 응답 품질의 트레이드오프 토론)

# %%
# !conda create -n py310_openai python=3.10 -y
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\admin\anaconda3\envs\py310_openai
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.9.9   |       haa95532_0         127 KB
#     libzlib-1.3.1              |       h02ab6af_0          64 KB
#     python-3.10.18             |       h981015d_0        16.2 MB
#     setuptools-78.1.1          |  py310haa95532_0         1.7 MB
#     wheel-0.45.1               |  py310haa95532_0         145 KB
#     zlib-1.3.1                 |       h02ab6af_0         113 KB
#     ------------------------------------------------------------
#                                            Total:        18.3 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# %%time
# 실습 2 코드
# 매우 긴 텍스트 예시 (실제로는 몇 페이지 분량의 글을 변수에 할당)
long_article = """
"카톡 내 챗GPT 기다려진다"...AI 페스타 카카오 부스 체험 열기 '후끈'
박서린 기자
입력
2025.10.01. 오후 1:44
수정
2025.10.01. 오후 2:20
기사원문
 추천
8
본문 요약봇
텍스트 음성 변환 서비스 사용하기
글자 크기 변경하기
SNS 보내기
인쇄하기
챗GPT·카나나 언어모델·보이스톡 녹음 등 신기능 공개…"곧바로 쓰고 싶다" 반응도
“안읽고 씹은 채팅을 요약해주는 기능이 가장 마음에 들더라고요. 실제로 나오면 자주 사용할 것 같아요. 전반적으로 전시가 정말 흥미롭네요. ”

지난 30일부터 막을 올린 국내 최대 규모 인공지능(AI) 행사 ‘AI 페스타 2025’ 첫날 마감 1시간 전까지 관람객의 발길이 끊이지 않았던 카카오 부스에 방문한 한 30대 남성은 이같은 소감을 남겼다. 카카오는 카카오톡에 적용한 챗GPT 시연과 카나나 언어모델들을 직접 체험할 수 있게 해 이목을 끌었다. 늦어도 내달 안에 완료될 업데이트 기능을 보여주면서 행사장에 꾸려진 부스 중 가장 흥미로웠다는 평가가 주를 이뤘다.

카카오는 오는 2일까지 서울 삼성동 코엑스에서 열린 과학기술정보통신부 인공지능(AI) 주간 공식 행사 ‘AI 페스타 2025’에서 부스를 마련한다. 카카오는 ‘모든 나를 위한 카카오 AI’를 주제로 행사에 참여해 ‘카카오 AI 스테이션’을 메인 테마로 부스를 차렸다.


9월 30일 AI 페스타 2025 카카오 부스에 들어가기 위해 줄을 서고 있는 관람객 모습. (사진=지디넷코리아)

카카오의 부스는 새로운 AI 서비스와 기능을 경험할 수 있는 ‘일상’ 공간과 AI 모델·생태계 플랫폼을 살펴볼 수 있는 ‘가능성’ 공간으로 구분됐다.

부스에 입장하면 왼쪽에 자리한 ‘일상’ 공간에서는 카카오톡(이하 카톡)에 적용된 챗GPT, 카나나 요약하기, 카나나 인 카카오톡을 선보였다. 먼저, 카카오와 챗GPT 만남 부분에서는 채팅방 안에 챗GPT 버튼을 도입해 카톡을 하면서 챗GPT에 궁금한 점을 물어볼 수 있는 시연이 이뤄졌다. 카카오톡 안에 챗GPT를 적용하는 기능은 이달 혹은 내달 초 안에 탑재될 예정이다.


AI 페스타 2025 카카오 부스 내 안읽씹한 채팅을 요약해주는 부스 시연. (사진=지디넷코리아)

카톡에 챗GPT가 적용되는 기능 외에도 ‘안읽씹(안 읽고 싶은 카톡)’ 채팅을 요약해주는 기능도 관람객의 가장 많은 관심을 받은 기능 중 하나로 꼽힌다. 해당 기능은 채팅방 폴더 내 안읽음 폴더에 자리한 채팅방의 대화 내용을 요약해준다. 예를 들어 읽지 않은 채팅방에서 러닝 약속이 잡혔다면, AI 대화요약이 “오늘 저녁 모임은 뚝섬 한강 공원에서 출발해 약 6~8km 코스로 진행되며 초보자도 참여 가능하다”고 안내해준다.


AI 페스타 2025 카카오 부스 내에서 보이스톡 통화 녹음 시연. (사진=지디넷코리아)

또 같은 부분에서 통화 녹음 기능을 업데이트할 보이스톡의 모습도 스마트폰 화면을 통해 직접 볼 수 있었다. 발신 혹은 통화 중에도 버튼 하나로 통화 녹음이 가능하며, 통화를 마친 후에는 내용을 바로 텍스트 파일로 변환해준다. 돋보기 화면을 이용하면 키워드 검색도 가능하고, 말풍선을 누르면 그 구간을 다시 들을 수 있다.


AI 페스타 2025 카카오 부스 내에서 카나나가 카카오톡 내에서 이용자에게 먼저 선톡하는 모습. (사진=지디넷코리아)

카나나 인 카카오톡에서는 AI가 채팅 맥락을 읽고 오늘의 브리핑을 제공하는 기능을 시연했다. 카나나가 먼저 카톡을 해 이용자에게 필요한 정보를 제공한다. 그 과정에서 카톡 예약하기와 멜론 등 카카오 서비스를 연동해 예약 기능을 제공한다. 가령 강남에서 20대 여성 3명이 가기 좋은 레스토랑에 대한 대화를 나눴다면, 카나나가 식당을 찾아 제안하고 예약하기 기능을 통해 예약까지 바로 이어지게 돕는다. 이 기능은 카카오의 온디바이스 AI 경량 모델을 다운로드 받으면 활용할 수 있다.

현장에서는 이달 중순부터 카톡 내 탑재될 카나나 CBT에 참여할 수 있도록 알림톡을 보내주는 QR을 등록할 수 있게 했다.

반대편인 오른쪽에서는 언어모델로서의 카나나를 직접 체험해볼 수 있었다. 카나나 모델 부문에서는 ‘카나나 언어모델’과 텍스트와 이미지를 함께 이해하는 멀티모달 언어모델 ‘카나나-v’를 실제로 이용 가능했다. 카나나 언어모델은 중형급이지만, 경량형 모델처럼 빨리 답변을 제공한다는 설명처럼 묻는 질문에 곧바로 답변을 받을 수 있었다.


AI 페스타 2025 카카오 부스 내에서 카나나 언어모델을 직접 체험한 모습. (사진=지디넷코리아)

멀티턴도 가능했다. 한국에서 가장 인구가 많은 광역시에 대해 질문했을 때 “서울특별시”라고 즉답했고, 바로 인구가 얼마냐고 묻자 “올해 9월 기준으로 서울특별시의 인구는 990만명”이라고 답변했다.

카나나 세이프가드 부문에서는 사람과 AI가 대화할 때 서로가 할 수 있는 유해한 질문과 응답을 걸러주는 거르망하는 역할을 하는 ‘카나나 세이프’의 모습을 확인할 수 있었다. 카나나 세이프가드는 현재 카카오의 AI 기반 서비스에 모두 적용돼 있으며, 앞으로 나올 모든 AI 서비스에 적용될 예정이다.

카카오 관계자는 “이 기능의 카나나가 한국어 특화 언어모델이다 보니 궤를 같이해 한국어에 특화돼 있다는 것이 장점”이라며 “민감한 독도 질문에도 올바른 답변을 내놓을 수 있다”고 설명했다.


AI 페스타 2025 카카오 부스 내 카나나 세이프카드의 시연 모습. (사진= 지디넷코리아)

국내 최초 모델 콘텍스트 프로토콜(MCP) 기반 개방형 플랫폼인 플레이MCP도 작동 방식을 눈으로 직접 보고, 체험해볼 수 있었다. 플레이 MCP는 개발자용 플랫폼으로, 카카오의 MCP 뿐만 아니라 개발자 개인이 가지고 있는 MCP를 올릴 수도 있다. 이 플랫폼에 AI 채팅을 열면, 플랫폼에 올라간 MCP를 활용해 답변을 주는 테스트도 해볼 수 있었다. 챗GPT는 이용자가 지난해 이날 들은 노래를 알 수 없지만, 플레이MCP에는 멜론 MCP가 들어있어 답변을 해주는 방식이다.

카카오는 향후 해당 MCP가 활용도가 좋다는 생각이 들면 MCP를 올린 개발자에게 연락을 해 카카오톡에 기능을 추가하는 것으로 목표로 한다.

‘가능성’ 공간을 모두 둘러본 한 40대 여성은 “기존이랑 업데이트 후 서비스가 어떻게 달라졌는지를 알 수 있어서 좋았다”며 “그냥 업데이트가 아닌 변경된 부분을 눈으로 볼 수 있어서 이해가 빨랐다. 다른 부스 대비 (카카오의 부스가)흥미롭다”고 평가했다.
박서린 기자(psr1229@zdnet.co.kr)
"""

summarization_prompt = f"다음 글의 핵심 내용을 3개의 불릿 포인트로 요약해줘:\n\n{long_article}"

response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[{"role": "user", "content": summarization_prompt}]
)  

response
# Out:
# CPU times: total: 15.6 ms
# Wall time: 9.95 s
# ...

# %%
print("📝 긴 글 요약 (GPT-5-nano):")
print("-" * 50)
answer = response.choices[0].message.content
print(answer)
# Out:
# 📝 긴 글 요약 (GPT-5-nano):
# --------------------------------------------------
# - 카카오톡에 챗GPT 탑재 시연과 함께 안읽씹 요약, 보이스톡 녹음→텍스트 변환, 카나나를 활용한 자동 브리핑·예약 제안 등 사용자 중심 AI 기능이 공개됐다.
#
# - 부스는 일상 공간과 가능성 공간으로 나뉘고, 개발자용 플레이MCP 오픈 플랫폼을 통해 MCP를 테스트·적용해 카톡 기능으로 확장하는 생태계 구축이 소개됐다.
#
# - 카나나 언어모델 및 멀티모달 카나나-v 체험, 카나나 세이프가드, 온-디바이스 경량 AI 등 기술 요소와 향후 업데이트 일정 및 안전성 강화 계획이 함께 시연됐다.

# %%
from IPython.display import display, Markdown
display(Markdown(answer))
# Out:
# - 카카오톡에 챗GPT 탑재 시연과 함께 안읽씹 요약, 보이스톡 녹음→텍스트 변환, 카나나를 활용한 자동 브리핑·예약 제안 등 사용자 중심 AI 기능이 공개됐다.
#
# - 부스는 일상 공간과 가능성 공간으로 나뉘고, 개발자용 플레이MCP 오픈 플랫폼을 통해 MCP를 테스트·적용해 카톡 기능으로 확장하는 생태계 구축이 소개됐다.
#
# - 카나나 언어모델 및 멀티모달 카나나-v 체험, 카나나 세이프가드, 온-디바이스 경량 AI 등 기술 요소와 향후 업데이트 일정 및 안전성 강화 계획이 함께 시연됐다.
