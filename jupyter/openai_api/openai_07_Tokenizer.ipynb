# %% [markdown]
# ※ 자료출처 : GPT-4, ChatGPT, 라마인덱스, 랭체인을 활용한 인공지능 프로그래밍
# * https://github.com/wikibook/openai-llm

# %% [markdown]
# ### OpenAI API

# %% [markdown]
# ### 4-7. 토크나이저 (Tokenizer)

# %% [markdown]
# * Moderation - OpenAI API Doc : https://platform.openai.com/docs/guides/moderation
#
# * 이용 정책 : https://openai.com/ko-KR/policies/usage-policies/

# %%
# import os
# os.environ["OPENAI_API_KEY"]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Openai / Tikoken 깃허브 : https://github.com/openai/tiktoken

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 한국어와 영어의 토큰 수 비교

# %% [markdown]
# #### 모델별 최대 토큰 수
# ![image.png](attachment:image.png)
