# %% [markdown]
# ※ 자료출처 : GPT-4, ChatGPT, 라마인덱스, 랭체인을 활용한 인공지능 프로그래밍
# * https://github.com/wikibook/openai-llm

# %% [markdown]
# ### OpenAI API

# %% [markdown]
# ## 4-3. 임베딩 (Embedding)

# %% [markdown]
# * Embeddings - OpenAI API  : https://platform.openai.com/docs/guides/embeddings/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Usage is priced per input token, below is an example of pricing pages of text per US dollar (assuming ~800 tokens per page):
#
# | MODEL                    | ~ PAGES PER DOLLAR | PERFORMANCE ON MTEB EVAL | MAX INPUT |
# |--------------------------|--------------------|--------------------------|-----------|
# | text-embedding-3-small    | 62,500             | 62.3%                    | 8191      |
# | text-embedding-3-large    | 9,615              | 64.6%                    | 8191      |
# | text-embedding-ada-002    | 12,500             | 61.0%                    | 8191      |
#
# * text-embeddding-3-small, text-embedding-3-large를 권장함 (2024)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### (1) 임베딩 생성

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### (2) 유사도 검색

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 유사도 검색을 수행하려면 index.search()를 사용한다.

# %% [markdown]
# ![image.png](attachment:image.png)
